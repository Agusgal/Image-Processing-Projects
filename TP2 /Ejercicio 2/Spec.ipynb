# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Primero generamos una imagen que representa un escalon corta duración en una dimensión y un escalon de mayor duración en la otra dimensión

# %%
# Blank canvas
f = np.zeros((30,30))
f[4:25, 12:17] = 1
plt.imshow(f, cmap='gray');

# %% [markdown]
# Podemos ver que la imagen contiene una barra blanca. Esto podemos pensarlos como una ventana rectangular de ancho 5 y alto 20 con una intensidad igual a 1.

# %%
# Perform FFT
F = np.fft.fft2(f)
F = np.fft.fftshift(F)
plt.imshow(np.abs(F), cmap='jet');

# %% [markdown]
# Del espectro podemos ver como ocurre la superposición de las dos Sinc a partir del espectro de los pulsos originales

# %%
plt.imshow(np.log(np.abs(F)), cmap='jet');
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
# Look at the phases
plt.imshow(np.angle(F), cmap='jet');
